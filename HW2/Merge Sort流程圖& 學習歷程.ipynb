# %% [markdown]
# 參考資料來源：https://www.geeksforgeeks.org/merge-sort/
# https://runestone.academy/runestone/books/published/pythonds/SortSearch/TheMergeSort.html
# 除了參考這個還有觀看影片了解邏輯。https://youtu.be/JSceec-wEyw
# 1首先我先透過畫結構圖來了解Merge Sort基本架構原則。
# 我初步想將num這串數分成兩部分，我要取的位置為第一個數跟最後一個數中間值。

# %% [markdown]
# 這個是我運用draw.io畫的流程圖。

# %%
from IPython.display import Image
Image(filename="/Users/chouhsinte/Downloads/mergesort.png")

# %%
def mergesort(num):
    low=num[0]
    high=num[-1]
    if len(num)>1:
        mid=(low+high)/2
        left_num=num[:mid]
        right_num=num[mid:]

# %% [markdown]
# 目前遇到一些瓶頸，不知道要怎麼繼續下去。發現python除法為//非/

# %%
def mergesort(num):
    low=num[0]
    high=num[-1]
    if len(num)>1:
        mid=(low+high)//2
        left_num=num[:mid]
        right_num=num[mid:]
        
        mergesort(left_num)
        mergesort(right_num)

# %%
def mergesort(num):
    low=num[0]
    high=num[-1]
    if len(num)>1:
        mid=(low+high)//2
        left_num=num[:mid]
        right_num=num[mid:]
        
        mergesort(left_num)
        mergesort(right_num)
        
        index=a=b=0
        
    for index<left_num:
        num[k]=left_num[index]
# Out:
#   File "<ipython-input-3-b2d8ff315ff0>", line 14
#     for index<left_num:
#              ^
# SyntaxError: invalid syntax

# %%
def mergesort(num):
    low=num[0]
    high=num[-1]
    if len(num)>1:
        mid=(low+high)//2
        left_num=num[:mid]
        right_num=num[mid:]
        
        mergesort(left_num)
        mergesort(right_num)
        
        r=m=l=0#r為最右邊的第一值，l為最左邊的第一值
        
    while l <len(left_num) and r<len(right_num):#左的第幾位數在小於這串樹以前都不會停止。同理右邊也是。
    
        if left_num[l]<= right_num[r]:
            num[m]=left_num[l]
            l=l+1

# %%
def mergesort(num):
    low=num[0]
    high=num[-1]
    if len(num)>1:
        mid=(low+high)//2
        left_num=num[:mid]
        right_num=num[mid:]
        
        mergesort(left_num)
        mergesort(right_num)
        
        r=m=l=0#r為最右邊的第一值，l為最左邊的第一值
        
    while l <len(left_num) and r<len(right_num):#左的第幾位數在小於這串樹以前都不會停止。同理右邊也是。
    
        if left_num[l]< right_num[r]def mergesort(num):
    low=num[0]
    high=num[-1]
    if len(num)>1:
        mid=(low+high)//2
        left_num=num[:mid]
        right_num=num[mid:]
        
        mergesort(left_num)
        mergesort(right_num)
        
        r=m=l=0#r為最右邊的第一值，l為最左邊的第一值
        
    while l <len(left_num) and r<len(right_num):#左的第幾位數在小於這串樹以前都不會停止。同理右邊也是。
    
        if right_num[r]< left_num[l]:
            num[m]=right[r]
            r=r+1
        else:
            num[m]=left_num[l]
            l=l+1
        m=m+1
# Out:
#   File "<ipython-input-3-d96a2d1681e7>", line 16
#     if left_num[l]< right_num[r]def mergesort(num):
#                                   ^
# SyntaxError: invalid syntax

# %%
def mergesort(num):
    low=num[0]
    high=num[-1]
    if len(num)>1:
        mid=(low+high)//2
        left_num=num[:mid]
        right_num=num[mid:]
        
        mergesort(left_num)
        mergesort(right_num)
        
        r=m=l=0#r為最右邊的第一值，l為最左邊的第一值
        
    while l <len(left_num) and r<len(right_num):#左的第幾位數在小於這串樹以前都不會停止。同理右邊也是。
    
        if left_num[l]< right_num[r]def mergesort(num):
    low=num[0]
    high=num[-1]
    if len(num)>1:
        mid=(low+high)//2
        left_num=num[:mid]
        right_num=num[mid:]
        
        mergesort(left_num)
        mergesort(right_num)
        
        r=m=l=0#r為最右邊的第一值，l為最左邊的第一值
        
    while l <len(left_num) and r<len(right_num):#左的第幾位數在小於這串樹以前都不會停止。同理右邊也是。
        if right_num[r]< left_num[l]:
            num[m]=right[r]
            r=r+1
        else:
            num[m]=left_num[l]
            l=l+1
        m=m+1
        
    while r< len(right_num):
        num[m]=right_num[r]
        
    while l <len(left_num):
        num[m]=left_num[l]
# Out:
#   File "<ipython-input-4-73be0600b9fa>", line 16
#     if left_num[l]< right_num[r]def mergesort(num):
#                                   ^
# SyntaxError: invalid syntax

# %%
num=[0,1,4,1,2]
mergesort(num)
# Out:
# ---------------------------------------------------------------------------
# UnboundLocalError                         Traceback (most recent call last)
# <ipython-input-7-261474a14515> in <module>
#       1 num=[0,1,4,1,2]
# ----> 2 mergesort(num)
#
# <ipython-input-6-e0a19def346c> in mergesort(num)
#       7         right_num=num[mid:]
#       8
# ----> 9         mergesort(left_num)
#      10         mergesort(right_num)
#      11
#
# <ipython-input-6-e0a19def346c> in mergesort(num)
#      12         r=m=l=0#r為最右邊的第一值，l為最左邊的第一值
#      13
# ---> 14     while l <len(left_num) and r<len(right_num):#左的第幾位數在小於這串樹以前都不會停止。同理右邊也是。
#      15         if right_num[r]< left_num[l]:
#      16             num[m]=right[r]
#
# UnboundLocalError: local variable 'l' referenced before assignment

# %%
def mergesort(num):
    low=num[0]
    high=num[-1]
    if len(num)>1:
        mid1=len(low)+len(high)
        mid=mid1//2
        left_num=num[:mid]
        right_num=num[mid:]
        
        mergesort(left_num)
        mergesort(right_num)
        
        r=m=l=0 #r為最右邊的第一值，l為最左邊的第一值
        
    while l <len(left_num) and r<len(right_num):#左的第幾位數在小於這串樹以前都不會停止。同理右邊也是。
        if right_num[r]< left_num[l]:
            num[m]=right[r]
            r=r+1
        else:
            num[m]=left_num[l]
            l=l+1
        m=m+1
        
    while r< len(right_num):
        num[m]=right_num[r]
        r=r+1
        m=m+1
    while l <len(left_num):
        num[m]=left_num[l]
        l=l+1
        m=m+1
num=[0,1,4,1,2]
mergesort(num)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-9-098c6d93829c> in <module>
#      31         m=m+1
#      32 num=[0,1,4,1,2]
# ---> 33 mergesort(num)
#
# <ipython-input-9-098c6d93829c> in mergesort(num)
#       3     high=num[-1]
#       4     if len(num)>1:
# ----> 5         mid1=len(low)+len(high)
#       6         mid=mid1//2
#       7         left_num=num[:mid]
#
# TypeError: object of type 'int' has no len()

# %% [markdown]
# 經過同學提醒，因為規定格式，所以前面必須統一用class來跑。
# 同時取中間數，不建議使用(high+low)//2這種語法，會減緩執行的速度。
# 只需要長度除2即可

# %%
class Solution(objecjt):
    def mergesort(self,num):
    if len(num)>1:
        mid=len(num)//2
        left_num=num[:mid]
        right_num=num[mid:]
        Solution().mergesort(left_num)
        Solution().mergesort(right_num)
        
        r=m=l=0 #r為最右邊的第一值，l為最左邊的第一值
        
    while l <len(left_num) and r<len(right_num):#左的第幾位數在小於這串樹以前都不會停止。同理右邊也是。
        if right_num[r]< left_num[l]:
            num[m]=right[r]
            r=r+1
        else:
            num[m]=left_num[l]
            l=l+1
        m=m+1
        
    while r< len(right_num):
        num[m]=right_num[r]
        r=r+1
        m=m+1
    while l <len(left_num):
        num[m]=left_num[l]
        l=l+1
        m=m+1
    return num
# Out:
#   File "<ipython-input-11-f77b8c3f76f2>", line 3
#     if len(num)>1:
#      ^
# IndentationError: expected an indented block

# %% [markdown]
# 我的間隔好像是有問題的，重新排序。

# %%
class Solution(objejct):
    def mergesort(self,num):
        if len(num)>1:
            mid=len(num)//2
            left_num=num[:mid]
            right_num=num[mid:]
            Solution().mergesort(left_num)
            Solution().mergesort(right_num)
            r=m=l=0 #r為最右邊的第一值，l為最左邊的第一值
            
            while l <len(left_num) and r<len(right_num):#左的第幾位數在小於這串樹以前都不會停止。同理右邊也是。
                if right_num[r]< left_num[l]:
                    num[m]=right[r]
                    r=r+1
                else:
                    num[m]=left_num[l]
                    l=l+1
                m=m+1
            while r< len(right_num):
                num[m]=right_num[r]
                r=r+1
                m=m+1
            while l <len(left_num):
                num[m]=left_num[l]
                l=l+1
                m=m+1
            return num
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-12-f25b9111b866> in <module>
# ----> 1 class Solution(objecjt):
#       2     def mergesort(self,num):
#       3         if len(num)>1:
#       4             mid=len(num)
#       5             left_num=num[:mid]
#
# NameError: name 'objecjt' is not defined

# %%
class Solution(object):
    def mergesort(self,num):
        if len(num)>1:
            mid=len(num)
            left_num=num[:mid]
            right_num=num[mid:]
            Solution().mergesort(left_num)
            Solution().mergesort(right_num)
            r=m=l=0 #r為最右邊的第一值，l為最左邊的第一值
            
            while l <len(left_num) and r<len(right_num):#左的第幾位數在小於這串樹以前都不會停止。同理右邊也是。
                if right_num[r]< left_num[l]:
                    num[m]=right[r]
                    r=r+1
                else:
                    num[m]=left_num[l]
                    l=l+1
                m=m+1
            while r< len(right_num):
                num[m]=right_num[r]
                r=r+1
                m=m+1
            while l <len(left_num):
                num[m]=left_num[l]
                l=l+1
                m=m+1
            return num

# %%
num=[0,3,1,5,1,2]
Solution().mergesort(num)
num
# Out:
# ---------------------------------------------------------------------------
# RecursionError                            Traceback (most recent call last)
# <ipython-input-14-de5c2e37f824> in <module>
#       1 num=[0,3,1,5,1,2]
# ----> 2 Solution().mergesort(num)
#       3 num
#
# <ipython-input-13-f7763e9a6058> in mergesort(self, num)
#       5             left_num=num[:mid]
#       6             right_num=num[mid:]
# ----> 7             Solution().mergesort(left_num)
#       8             Solution().mergesort(right_num)
#       9             r=m=l=0 #r為最右邊的第一值，l為最左邊的第一值
#
# ... last 1 frames repeated, from the frame below ...
#
# <ipython-input-13-f7763e9a6058> in mergesort(self, num)
#       5             left_num=num[:mid]
#       6             right_num=num[mid:]
# ----> 7             Solution().mergesort(left_num)
#       8             Solution().mergesort(right_num)
#       9             r=m=l=0 #r為最右邊的第一值，l為最左邊的第一值
#
# RecursionError: maximum recursion depth exceeded while calling a Python object

# %% [markdown]
# 我發現我的mid忘記//2

# %%
class Solution(object):
    def mergesort(self,num):
        if len(num)>1:
            mid=len(num)//2
            left_num=num[:mid]
            right_num=num[mid:]
            Solution().mergesort(left_num)
            Solution().mergesort(right_num)
            r=m=l=0 #r為最右邊的第一值，l為最左邊的第一值
            
            while l <len(left_num) and r<len(right_num):#左的第幾位數在小於這串樹以前都不會停止。同理右邊也是。
                if right_num[r]< left_num[l]:
                    num[m]=right[r]
                    r=r+1
                else:
                    num[m]=left_num[l]
                    l=l+1
                m=m+1
            while r< len(right_num):
                num[m]=right_num[r]
                r=r+1
                m=m+1
            while l <len(left_num):
                num[m]=left_num[l]
                l=l+1
                m=m+1
            return num

# %%
num=[0,3,1,5,1,2]
Solution().mergesort(num)
num
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-17-de5c2e37f824> in <module>
#       1 num=[0,3,1,5,1,2]
# ----> 2 Solution().mergesort(num)
#       3 num
#
# <ipython-input-16-b2c37186d7de> in mergesort(self, num)
#       5             left_num=num[:mid]
#       6             right_num=num[mid:]
# ----> 7             Solution().mergesort(left_num)
#       8             Solution().mergesort(right_num)
#       9             r=m=l=0 #r為最右邊的第一值，l為最左邊的第一值
#
# <ipython-input-16-b2c37186d7de> in mergesort(self, num)
#       6             right_num=num[mid:]
#       7             Solution().mergesort(left_num)
# ----> 8             Solution().mergesort(right_num)
#       9             r=m=l=0 #r為最右邊的第一值，l為最左邊的第一值
#      10
#
# <ipython-input-16-b2c37186d7de> in mergesort(self, num)
#      11             while l <len(left_num) and r<len(right_num):#左的第幾位數在小於這串樹以前都不會停止。同理右邊也是。
#      12                 if right_num[r]< left_num[l]:
# ---> 13                     num[m]=right[r]
#      14                     r=r+1
#      15                 else:
#
# NameError: name 'right' is not defined

# %% [markdown]
# 應該為right_num非right

# %%
class Solution(object):
    def mergesort(self,num):
        if len(num)>1:
            mid=len(num)//2
            left_num=num[:mid]
            right_num=num[mid:]
            Solution().mergesort(left_num)
            Solution().mergesort(right_num)
            r=m=l=0 #r為最右邊的第一值，l為最左邊的第一值
            
            while l <len(left_num) and r<len(right_num):#左的第幾位數在小於這串樹以前都不會停止。同理右邊也是。
                if right_num[r]< left_num[l]:
                    num[m]=right_num[r]
                    r=r+1
                else:
                    num[m]=left_num[l]
                    l=l+1
                m=m+1
            while r< len(right_num):
                num[m]=right_num[r]
                r=r+1
                m=m+1
            while l <len(left_num):
                num[m]=left_num[l]
                l=l+1
                m=m+1
            return num

# %%
num=[0,3,1,5,1,2]
Solution().mergesort(num)
num
# Out:
# [0, 1, 1, 2, 3, 5]
