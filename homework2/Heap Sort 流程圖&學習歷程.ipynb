# %% [markdown]
# 參考資料：https://www.geeksforgeeks.org/python-program-for-heap-sort/
# 同學厲彥伯有教導我觀念架構，邏輯推導。
#
# 初步想法：每一個三角形組合，最上面的是最大的，所以我用parents下面分別為children_left和children_right。
# num 為這組數字的list x為總共可以有幾個heap i就是第幾個heap

# %% [markdown]
# 此篇為我個人運用draw.io的分解圖。

# %%
from IPython.display import Image
Image(filename="/Users/chouhsinte/Downloads/heapsort1.png")

# %%
from IPython.display import Image
Image(filename="/Users/chouhsinte/Downloads/heapsort2.png")

# %%
from IPython.display import Image
Image(filename="/Users/chouhsinte/Downloads/heapsort3.png")

# %%
from IPython.display import Image
Image(filename="/Users/chouhsinte/Downloads/heapsort4.png")

# %%
from IPython.display import Image
Image(filename="/Users/chouhsinte/Downloads/heapsort5.png")

# %%
def heapify(num, x, i): 
    parents = i  
    children_left = 2 * i + 1     
    children_wright = 2 * i + 2

# %% [markdown]
# 再來就是要比較他們的大小，假如parents大於children_left，那麼就可以不用更動，但反之假如小於的話，順序去做對調。那比較完children_left這個部分，再去比較children_right。

# %%
if num[children_left]>num[i]:
    parents= children_left
if num[children_right]>num[i]:
    parents= children_right
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-7-7cfc1496f292> in <module>
# ----> 1 if num[children_left]>num[i]:
#       2     parents= children_left
#       3 if num[children_right]>num[i]:
#       4     parents= children_right
#
# NameError: name 'num' is not defined

# %% [markdown]
# 發現有錯，發現說num沒有被定義，嘗試再加一下東西

# %%
if num[children_left]>num[i]:
    parents= children_left
if num[children_right]>num[i]:
    parents= children_right
if largest!=i:
    num[i],num[parents]=num[parents],num[i]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-8-7732f696af50> in <module>
# ----> 1 if num[children_left]>num[i]:
#       2     parents= children_left
#       3 if num[children_right]>num[i]:
#       4     parents= children_right
#       5 if largest!=i:
#
# NameError: name 'num' is not defined

# %% [markdown]
# 還是有錯誤，所以我去找尋一開始查找資料的地方發現

# %%
def heapify(num, x, i): 
    parents = i  
    children_left = 2 * i + 1     
    children_wright = 2 * i + 2
if num[children_left]>num[i]:
    parents= children_left
if num[children_right]>num[parents]:
    parents= children_right
if parents!=i:
    num[i],num[parents]=num[parents],num[i]
    heapify(num,x,parents)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-11-442e3225a7ef> in <module>
#       3     children_left = 2 * i + 1
#       4     children_wright = 2 * i + 2
# ----> 5 if num[children_left]>num[i]:
#       6     parents= children_left
#       7 if num[children_right]>num[parents]:
#
# NameError: name 'num' is not defined

# %%
def heapify(num, x, i): 
    parents = i  
    children_left = 2 * i + 1     
    children_wright = 2 * i + 2
if num[children_left]>num[i]and x<children_left:
    parents= children_left
if num[children_right]>num[parents] and x<children_right:
    parents= children_right
if parents!=i:
    num[i],num[parents]=num[parents],num[i]
    heapify(num,x,largest)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-12-cde6bf879220> in <module>
#       3     children_left = 2 * i + 1
#       4     children_wright = 2 * i + 2
# ----> 5 if num[children_left]>num[i]and x<children_left:
#       6     parents= children_left
#       7 if num[children_right]>num[parents] and x<children_right:
#
# NameError: name 'num' is not defined

# %% [markdown]
# 過程中忘記這個range(start, stop,step)。

# %%
def heapify(arr, x, i): 
    parents = i  
    children_left = 2 * i + 1     
    children_wright = 2 * i + 2
if arr[children_left]>arr[i]and x<children_left:
    parents= children_left
if arr[children_right]>arr[parents] and x<children_right:
    parents= children_right
if parents!=i:
    arr[i],arr[parents]=arr[parents],arr[i]
    heapify(arr,x,largest)
def heapsort(arr):
    x=len(arr)
for i in range(x,-1,-1):
    heapify(arr,x,i)
for i in range(x-1, 0, -1): 
        arr[i], arr[0] = arr[0], arr[i]   # swap 
        heapify(arr, i, 0)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-2afcd3031a1f> in <module>
#       3     children_left = 2 * i + 1
#       4     children_wright = 2 * i + 2
# ----> 5 if arr[children_left]>arr[i]and x<children_left:
#       6     parents= children_left
#       7 if arr[children_right]>arr[parents] and x<children_right:
#
# NameError: name 'arr' is not defined

# %%
class Solution():
    def heapify(self,arr, x, i):
        parents= i 
        children_left=2*i+1
        children_right=2*1+2
        
        if children_left<x and arr[parents]<arr[children_left]:
            parents=children_left
        if children_right<x and arr[parents]<arr[children_right]:
            parents=children_right
        if parents!= i:
            arr[parents],arr[i]=arr[i],arr[parents]
            Solution().heapify(arr,x,parents)
    def heapsort(self,arr):
        x=len(arr)
        Solution().heap(arr)

# %%
arr = [4, 13, 12, 49, 30, 16, 3, 2, 0]
Solution().heapsort(arr)
arr
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-3-3e17e8f9dfa9> in <module>
#       1 arr = [4, 13, 12, 49, 30, 16, 3, 2, 0]
# ----> 2 Solution().heapsort(arr)
#       3 arr
#
# <ipython-input-2-50bc84bc803b> in heapsort(self, arr)
#      14     def heapsort(self,arr):
#      15         x=len(arr)
# ---> 16         Solution().heap(arr)
#      17
#      18
#
# AttributeError: 'Solution' object has no attribute 'heap'

# %%
class Solution():
    def heapify(self,arr, x, i):
        parents= i 
        children_left=2*i+1
        children_right=2*1+2
        
        if children_left<x and arr[parents]<arr[children_left]:
            parents=children_left
        if children_right<x and arr[parents]<arr[children_right]:
            parents=children_right
        if parents!= i:
            arr[parents],arr[i]=arr[i],arr[parents]
            Solution().heapify(arr,x,parents)
    def heapsort(self,arr):
        x=len(arr)
        heap(arr)
        
    def heap(self,arr):
        index=x/2-1
        while index >=1:
            heapify(arr,x,index)
            index=index-1

# %%
arr = [4, 13, 12, 49, 30, 16, 3, 2, 0]
Solution().heapsort(arr)
arr
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-5-3e17e8f9dfa9> in <module>
#       1 arr = [4, 13, 12, 49, 30, 16, 3, 2, 0]
# ----> 2 Solution().heapsort(arr)
#       3 arr
#
# <ipython-input-4-6e38d6a0d42f> in heapsort(self, arr)
#      14     def heapsort(self,arr):
#      15         x=len(arr)
# ---> 16         heap(arr)
#      17
#      18     def heap(self,arr):
#
# NameError: name 'heap' is not defined

# %%
class Solution():
    def heapify(self,arr, x, i):
        parents= i 
        children_left=2*i+1
        children_right=2*1+2
        
        if children_left<x and arr[parents]<arr[children_left]:
            parents=children_left
        if children_right<x and arr[parents]<arr[children_right]:
            parents=children_right
        if parents!= i:
            arr[parents],arr[i]=arr[i],arr[parents]
            Solution().heapify(arr,x,parents)
    def heapsort(self,arr):
        x=len(arr)
        heap(arr)
        while x > 1:
            arr[0], arr[x - 1] = arr[x - 1], arr[0]
            x =x-1
            Solution().heapify(arr, x, 0)
        
    def heap(self,arr):
        index=x/2-1
        while index >=1:
            heapify(arr,x,index)
            index=index-1

# %%
arr = [4, 13, 12, 49, 30, 16, 3, 2, 0]
Solution().heapsort(arr)
arr
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-7-3e17e8f9dfa9> in <module>
#       1 arr = [4, 13, 12, 49, 30, 16, 3, 2, 0]
# ----> 2 Solution().heapsort(arr)
#       3 arr
#
# <ipython-input-6-8b162786be76> in heapsort(self, arr)
#      14     def heapsort(self,arr):
#      15         x=len(arr)
# ---> 16         heap(arr)
#      17         while x > 1:
#      18             arr[0], arr[x - 1] = arr[x - 1], arr[0]
#
# NameError: name 'heap' is not defined

# %%
class solution():
    def heapify(arr, x, i):
        parents= i 
        children_left=2*i+1
        children_right=2*1+2
        
        if children_left<x and arr[parents]<arr[children_left]:
            parents=children_left
        if children_right<x and arr[parents]<arr[children_right]:
            parents=children_right
        if parents!= i:
            arr[parents],arr[i]=arr[i],arr[parents]
            solution().heapify(arr,x,parents)
    def heapsort(arr):
        x=len(arr)
        heap(arr)
        while x > 1:
            arr[0], arr[x - 1] = arr[x - 1], arr[0]
            x =x-1
            solution().heapify( x, 0)
        
    def heap(arr):
        index=x/2-1
        while index >=1:
            solution().heapify(arr,x,index)
            index=index-1

# %%
arr = [4, 13, 12, 49, 30, 16, 3, 2, 0]
solution().heapsort(arr)
arr
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-11-e19a404c93fc> in <module>
#       1 arr = [4, 13, 12, 49, 30, 16, 3, 2, 0]
# ----> 2 solution().heapsort(arr)
#       3 arr
#
# TypeError: heapsort() takes 1 positional argument but 2 were given

# %%
class solution():
    def heapify(self,arr, x, i):
        parents= i 
        children_left=2*i+1
        children_right=2*1+2
        
        if children_left<x and arr[parents]<arr[children_left]:
            parents=children_left
        if children_right<x and arr[parents]<arr[children_right]:
            parents=children_right
        if parents!= i:
            arr[parents],arr[i]=arr[i],arr[parents]
            solution().heapify(arr,x,parents)
    def heapsort(self,arr):
        x=len(arr)
        solution().heap(arr)
        while x > 1:
            arr[0], arr[x - 1] = arr[x - 1], arr[0]
            x =x-1
            solution().heapify( x, 0)
        
    def heap(self,arr):
        index=x/2-1
        while index >=1:
            solution().heapify(arr,x,index)
            index=index-1

# %%
arr = [4, 13, 12, 49, 30, 16, 3, 2, 0]
solution().heapsort(arr)
arr
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-16-e19a404c93fc> in <module>
#       1 arr = [4, 13, 12, 49, 30, 16, 3, 2, 0]
# ----> 2 solution().heapsort(arr)
#       3 arr
#
# <ipython-input-15-53745e152472> in heapsort(self, arr)
#      14     def heapsort(self,arr):
#      15         x=len(arr)
# ---> 16         solution().heap(arr)
#      17         while x > 1:
#      18             arr[0], arr[x - 1] = arr[x - 1], arr[0]
#
# <ipython-input-15-53745e152472> in heap(self, arr)
#      21
#      22     def heap(self,arr):
# ---> 23         index=x/2-1
#      24         while index >=1:
#      25             solution().heapify(arr,x,index)
#
# NameError: name 'x' is not defined

# %%
class solution():
    def heapify(self,arr, x, i):
        parents= i 
        children_left=2*i+1
        children_right=2*1+2
        
        if children_left<x and arr[parents]<arr[children_left]:
            arr[parents],arr[children_left]=arr[children_left],arr[parents]
        if children_right<x and arr[parents]<arr[children_right]:
            parents=children_right
        if parents!= i:
            arr[parents],arr[i]=arr[i],arr[parents]
            solution().heapify(arr,x,parents)
    def heapsort(self,arr):
        x=len(arr)
        solution().heap(arr)
        while x > 1:
            arr[0], arr[x - 1] = arr[x - 1], arr[0]
            x =x-1
            solution().heapify( x, 0)
        
    def heap(self,arr):
        index=int(x/2-1)
        while index >=0:
            solution().heapify(arr,x,index)
            index=index-1

# %%
arr = [0, 7, 12, 31, 30, 16, 3, 5, 2]
solution().heapsort(arr)
arr
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-4-e19a404c93fc> in <module>
#       1 arr = [4, 13, 12, 49, 30, 16, 3, 2, 0]
# ----> 2 solution().heapsort(arr)
#       3 arr
#
# <ipython-input-3-affa1871ab35> in heapsort(self, arr)
#      14     def heapsort(self,arr):
#      15         x=len(arr)
# ---> 16         solution().heap(arr)
#      17         while x > 1:
#      18             arr[0], arr[x - 1] = arr[x - 1], arr[0]
#
# <ipython-input-3-affa1871ab35> in heap(self, arr)
#      21
#      22     def heap(self,arr):
# ---> 23         index=int(x/2-1)
#      24         while index >=0:
#      25             solution().heapify(arr,x,index)
#
# NameError: name 'x' is not defined

# %%
class solution():
    def heapify(arr, x, i):
        parents= i 
        children_left=2*i+1
        children_right=2*i+2
        
        if  arr[parents]<arr[children_left] and children_left<x:
            arr[parents],arr[children_left]=arr[children_left],arr[parents]
        if  arr[parents]<arr[children_right] and children_right<x:
            parents=children_right
        if parents!= i:
            arr[parents],arr[i]=arr[i],arr[parents]
            heapify(arr,x,parents)
    def heapsort(arr):
        x=len(arr)
        heap(arr)
        while x > 1:
            arr[0], arr[x - 1] = arr[x - 1], arr[0]
            x =x-1
            heapify(arr,x, 0)
        return arr
    def heap(arr):
        x=len(arr)
        index=int(x/2-1) 
        while index >=0:
            heapify(arr,x,index)
            index=index-1

# %%
arr = [0, 7, 12, 31, 30, 16, 3, 5,2]
solution().heapsort(arr)
arr
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-48-eff6c406c303> in <module>
#       1 arr = [0, 7, 12, 31, 30, 16, 3, 5,2]
# ----> 2 solution().heapsort(arr)
#       3 arr
#
# TypeError: heapsort() takes 1 positional argument but 2 were given

# %% [markdown]
# 不清楚為什麼還是有錯，無法執行。
